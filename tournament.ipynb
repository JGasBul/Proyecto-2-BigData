# %% [markdown]
# # Big Data - Proyecto MLLib
# # Gradient Boosted Trees - Configuración Optimizada para Torneo
# # Basado en resultados previos con F1=0.8580

# %% [markdown]
# # INICIALIZACIÓN Y CONFIGURACIÓN

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark.ml.feature import *
from pyspark.ml.classification import GBTClassifier
from pyspark.ml.evaluation import BinaryClassificationEvaluator, MulticlassClassificationEvaluator
from pyspark.ml import Pipeline
import time
import json

# Configuración Spark optimizada para recursos limitados
spark = SparkSession.builder \
    .appName("GBT Final - Hotel Booking Cancellation") \
    .config("spark.sql.adaptive.enabled", "true") \
    .config("spark.sql.adaptive.coalescePartitions.enabled", "true") \
    .config("spark.driver.memory", "3g") \
    .config("spark.executor.memory", "3g") \
    .config("spark.driver.maxResultSize", "1g") \
    .config("spark.serializer", "org.apache.spark.serializer.KryoSerializer") \
    .getOrCreate()

print("=== CONFIGURACIÓN SPARK OPTIMIZADA ===")
print(f"Spark Version: {spark.version}")
print("Configuración: Sin Grid Search, solo mejor modelo")
# Out:
# 25/06/11 20:21:22 WARN Utils: Your hostname, jgasbul-VirtualBox resolves to a loopback address: 127.0.1.1; using 10.0.2.15 instead (on interface enp0s3)
# 25/06/11 20:21:22 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/06/11 20:21:23 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# === CONFIGURACIÓN SPARK OPTIMIZADA ===
# Spark Version: 3.5.5
# Configuración: Sin Grid Search, solo mejor modelo

# %% [markdown]
# # CARGA Y ANÁLISIS INICIAL DE DATOS

# %%
print("=== CARGANDO DATOS ===")
df = spark.read.csv("train.csv", header=True, inferSchema=True)
print(f"Datos cargados: {df.count()} registros, {len(df.columns)} columnas")

# Verificación rápida de la distribución de clases
class_distribution = df.groupBy("is_canceled").count().orderBy("is_canceled")
print("\n=== DISTRIBUCIÓN DE CLASES ===")
class_distribution.show()

# Calcular proporción para referencia
total_records = df.count()
canceled_count = df.filter(col("is_canceled") == 1).count()
print(f"Cancelaciones: {canceled_count}/{total_records} ({canceled_count/total_records*100:.1f}%)")
# Out:
# === CARGANDO DATOS ===
# Datos cargados: 55531 registros, 23 columnas
#
# === DISTRIBUCIÓN DE CLASES ===
# +-----------+-----+
# |is_canceled|count|
# +-----------+-----+
# |          0|32418|
# |          1|23113|
# +-----------+-----+
#
# Cancelaciones: 23113/55531 (41.6%)

# %% [markdown]
# # DEFINICIÓN DE COLUMNAS Y FEATURE ENGINEERING

# %%
print("=== CONFIGURANDO TRANSFORMACIONES SIMPLIFICADAS ===")

# Definir columnas por tipo (simplificado para mejor rendimiento)
numeric_cols = ["lead_time", "arrival_date_week_number", "stays_in_weekend_nights", 
                "stays_in_week_nights", "adults", "children", "babies", 
                "previous_cancellations", "previous_bookings_not_canceled", 
                "booking_changes", "days_in_waiting_list", "adr", 
                "required_car_parking_spaces", "total_of_special_requests"]

# Solo las categóricas más importantes para reducir complejidad
categorical_cols = ["meal", "market_segment", "deposit_type", "customer_type"]

boolean_cols = ["is_repeated_guest"]
target_col = "is_canceled"

print(f"Columnas numéricas: {len(numeric_cols)}")
print(f"Columnas categóricas (simplificadas): {len(categorical_cols)}")
print(f"Columnas booleanas: {len(boolean_cols)}")
# Out:
# === CONFIGURANDO TRANSFORMACIONES SIMPLIFICADAS ===
# Columnas numéricas: 14
# Columnas categóricas (simplificadas): 4
# Columnas booleanas: 1

# %% [markdown]
# # FEATURE ENGINEERING AVANZADO

# %%
print("\n=== FEATURE ENGINEERING ESENCIAL ===")

# Solo las características derivadas más importantes
df = df.withColumn("total_nights", col("stays_in_weekend_nights") + col("stays_in_week_nights")) \
       .withColumn("total_guests", col("adults") + coalesce(col("children"), lit(0)) + col("babies")) \
       .withColumn("adr_per_person", 
                   when(col("total_guests") > 0, col("adr") / col("total_guests")).otherwise(col("adr"))) \
       .withColumn("has_special_requests", (col("total_of_special_requests") > 0).cast("int")) \
       .withColumn("has_previous_cancellations", (col("previous_cancellations") > 0).cast("int")) \
       .withColumn("booking_changes_flag", (col("booking_changes") > 0).cast("int")) \
       .withColumn("lead_time_log", log(col("lead_time") + 1)) \
       .withColumn("adr_log", log(col("adr") + 1))

print("Feature engineering completado")

# Actualizar listas de columnas
derived_numeric_cols = ["total_nights", "total_guests", "adr_per_person", "lead_time_log", "adr_log"]
derived_binary_cols = ["has_special_requests", "has_previous_cancellations", "booking_changes_flag"]

all_numeric_cols = numeric_cols + derived_numeric_cols
all_binary_cols = boolean_cols + derived_binary_cols
# Out:
# === FEATURE ENGINEERING ESENCIAL ===
# Feature engineering completado

# %% [markdown]
# # PIPELINE DE TRANSFORMACIONES OPTIMIZADO

# %%
print("=== CONSTRUYENDO PIPELINE SIMPLIFICADO ===")

# FASE 1: Imputación
imputer = Imputer(
    inputCols=["children"],
    outputCols=["children_imputed"],
    strategy="median"
)

# FASE 2: Encoding categórico simplificado (solo StringIndexer)
string_indexers = []
indexed_categorical_cols = []

for col_name in categorical_cols:
    indexer = StringIndexer(
        inputCol=col_name,
        outputCol=f"{col_name}_indexed",
        handleInvalid="keep"
    )
    string_indexers.append(indexer)
    indexed_categorical_cols.append(f"{col_name}_indexed")

# FASE 3: Escalado de variables numéricas
numeric_cols_for_scaling = [col for col in all_numeric_cols if col != "children"] + ["children_imputed"]

assembler_for_scaling = VectorAssembler(
    inputCols=numeric_cols_for_scaling,
    outputCol="numeric_features_raw"
)

scaler = StandardScaler(
    inputCol="numeric_features_raw",
    outputCol="numeric_features_scaled",
    withStd=True,
    withMean=True
)

# FASE 4: Ensamblador final simplificado
all_feature_cols = ["numeric_features_scaled"] + indexed_categorical_cols + all_binary_cols

final_assembler = VectorAssembler(
    inputCols=all_feature_cols,
    outputCol="features"
)

print(f"Pipeline simplificado con {len(all_feature_cols)} tipos de características")
# Out:
# === CONSTRUYENDO PIPELINE SIMPLIFICADO ===
# Pipeline simplificado con 9 tipos de características

# %% [markdown]
# # APLICAR TRANSFORMACIONES Y DIVISIÓN DE DATOS

# %%
print("=== APLICANDO TRANSFORMACIONES ===")

# Pipeline simplificado
preprocessing_stages = [imputer] + string_indexers + [
    assembler_for_scaling,
    scaler,
    final_assembler
]

preprocessing_pipeline = Pipeline(stages=preprocessing_stages)

# Fit y transform
fitted_pipeline = preprocessing_pipeline.fit(df)
df_transformed = fitted_pipeline.transform(df)

print("Transformaciones aplicadas correctamente")

# Verificar dimensiones
sample_features = df_transformed.select("features").first()[0]
feature_dimension = len(sample_features)
print(f"Dimensión del vector de características: {feature_dimension}")

# División de datos
print("\n=== DIVISIÓN DE DATOS ===")
train_df, val_df = df_transformed.select("features", target_col).randomSplit([0.8, 0.2], seed=42)

# Cachear para mejor rendimiento
train_df.cache()
val_df.cache()

train_count = train_df.count()
val_count = val_df.count()
print(f"Datos de entrenamiento: {train_count} registros")
print(f"Datos de validación: {val_count} registros")
# Out:
# === APLICANDO TRANSFORMACIONES ===
# 25/06/11 20:21:36 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# Transformaciones aplicadas correctamente
# Dimensión del vector de características: 27
#
# === DIVISIÓN DE DATOS ===
# [Stage 37:=============================>                            (1 + 1) / 2]
# Datos de entrenamiento: 44413 registros
# Datos de validación: 11118 registros

# %% [markdown]
# # CONFIGURACIÓN OPTIMIZADA DE GBT

# %%
print("=== CONFIGURACIÓN ÓPTIMA DE GBT (SIN GRID SEARCH) ===")

# Configuración óptima basada en experiment_results.json
gbt_final = GBTClassifier(
    featuresCol="features",
    labelCol=target_col,
    maxDepth=7,           # Optimal parameter
    maxIter=150,          # Optimal parameter  
    stepSize=0.2,         # Optimal parameter
    subsamplingRate=1.0,  # Optimal parameter
    featureSubsetStrategy="all",
    seed=42,
    minInstancesPerNode=1,
    maxBins=32,
    lossType="logistic",
    validationTol=0.01,
    cacheNodeIds=True,
    checkpointInterval=10
)

print("Configuración GBT final:")
print(f"  - maxDepth: {gbt_final.getMaxDepth()}")
print(f"  - maxIter: {gbt_final.getMaxIter()}")
print(f"  - stepSize: {gbt_final.getStepSize()}")
print(f"  - subsamplingRate: {gbt_final.getSubsamplingRate()}")
print("  - Parámetros basados en mejores resultados previos (F1=0.8580)")
# Out:
# === CONFIGURACIÓN ÓPTIMA DE GBT (SIN GRID SEARCH) ===
# Configuración GBT final:
#   - maxDepth: 7
#   - maxIter: 150
#   - stepSize: 0.2
#   - subsamplingRate: 1.0
#   - Parámetros basados en mejores resultados previos (F1=0.8580)

# %% [markdown]
# # ENTRENAMIENTO DEL MODELO FINAL

# %%
print("\n=== ENTRENAMIENTO DEL MODELO FINAL ===")
print("Iniciando entrenamiento con configuración óptima...")

start_time = time.time()
gbt_model = gbt_final.fit(train_df)
training_time = time.time() - start_time

print(f"✅ Entrenamiento completado en {training_time:.1f}s")
# Out:
# === ENTRENAMIENTO DEL MODELO FINAL ===
# Iniciando entrenamiento con configuración óptima...
# 25/06/11 20:22:23 WARN DAGScheduler: Broadcasting large task binary with size 1010.7 KiB
# 25/06/11 20:22:23 WARN DAGScheduler: Broadcasting large task binary with size 1011.3 KiB
# 25/06/11 20:22:23 WARN DAGScheduler: Broadcasting large task binary with size 1011.7 KiB
# 25/06/11 20:22:23 WARN DAGScheduler: Broadcasting large task binary with size 1012.1 KiB
# 25/06/11 20:22:23 WARN DAGScheduler: Broadcasting large task binary with size 1012.8 KiB
# 25/06/11 20:22:24 WARN DAGScheduler: Broadcasting large task binary with size 1013.6 KiB
# 25/06/11 20:22:24 WARN DAGScheduler: Broadcasting large task binary with size 1014.8 KiB
# 25/06/11 20:22:24 WARN DAGScheduler: Broadcasting large task binary with size 1026.0 KiB
# 25/06/11 20:22:24 WARN DAGScheduler: Broadcasting large task binary with size 1026.5 KiB
# 25/06/11 20:22:24 WARN DAGScheduler: Broadcasting large task binary with size 1026.9 KiB
# 25/06/11 20:22:24 WARN DAGScheduler: Broadcasting large task binary with size 1027.4 KiB
# 25/06/11 20:22:24 WARN DAGScheduler: Broadcasting large task binary with size 1028.0 KiB
# 25/06/11 20:22:24 WARN DAGScheduler: Broadcasting large task binary with size 1028.8 KiB
# 25/06/11 20:22:24 WARN DAGScheduler: Broadcasting large task binary with size 1030.0 KiB
# 25/06/11 20:22:24 WARN DAGScheduler: Broadcasting large task binary with size 1041.3 KiB
# 25/06/11 20:22:25 WARN DAGScheduler: Broadcasting large task binary with size 1041.8 KiB
# 25/06/11 20:22:25 WARN DAGScheduler: Broadcasting large task binary with size 1042.2 KiB
# 25/06/11 20:22:25 WARN DAGScheduler: Broadcasting large task binary with size 1042.7 KiB
# 25/06/11 20:22:25 WARN DAGScheduler: Broadcasting large task binary with size 1043.2 KiB
# 25/06/11 20:22:25 WARN DAGScheduler: Broadcasting large task binary with size 1044.0 KiB
# 25/06/11 20:22:25 WARN DAGScheduler: Broadcasting large task binary with size 1045.1 KiB
# 25/06/11 20:22:25 WARN DAGScheduler: Broadcasting large task binary with size 1056.1 KiB
# 25/06/11 20:22:25 WARN DAGScheduler: Broadcasting large task binary with size 1056.7 KiB
# 25/06/11 20:22:25 WARN DAGScheduler: Broadcasting large task binary with size 1057.1 KiB
# 25/06/11 20:22:25 WARN DAGScheduler: Broadcasting large task binary with size 1057.5 KiB
# 25/06/11 20:22:26 WARN DAGScheduler: Broadcasting large task binary with size 1058.1 KiB
# 25/06/11 20:22:26 WARN DAGScheduler: Broadcasting large task binary with size 1058.9 KiB
# 25/06/11 20:22:26 WARN DAGScheduler: Broadcasting large task binary with size 1060.1 KiB
# 25/06/11 20:22:26 WARN DAGScheduler: Broadcasting large task binary with size 1070.2 KiB
# 25/06/11 20:22:26 WARN DAGScheduler: Broadcasting large task binary with size 1070.7 KiB
# 25/06/11 20:22:26 WARN DAGScheduler: Broadcasting large task binary with size 1071.1 KiB
# 25/06/11 20:22:26 WARN DAGScheduler: Broadcasting large task binary with size 1071.6 KiB
# 25/06/11 20:22:26 WARN DAGScheduler: Broadcasting large task binary with size 1072.2 KiB
# 25/06/11 20:22:26 WARN DAGScheduler: Broadcasting large task binary with size 1072.8 KiB
# 25/06/11 20:22:27 WARN DAGScheduler: Broadcasting large task binary with size 1074.0 KiB
# 25/06/11 20:22:27 WARN DAGScheduler: Broadcasting large task binary with size 1084.8 KiB
# 25/06/11 20:22:27 WARN DAGScheduler: Broadcasting large task binary with size 1085.3 KiB
# 25/06/11 20:22:27 WARN DAGScheduler: Broadcasting large task binary with size 1085.7 KiB
# 25/06/11 20:22:27 WARN DAGScheduler: Broadcasting large task binary with size 1086.2 KiB
# 25/06/11 20:22:27 WARN DAGScheduler: Broadcasting large task binary with size 1086.7 KiB
# 25/06/11 20:22:27 WARN DAGScheduler: Broadcasting large task binary with size 1087.5 KiB
# 25/06/11 20:22:27 WARN DAGScheduler: Broadcasting large task binary with size 1088.6 KiB
# 25/06/11 20:22:27 WARN DAGScheduler: Broadcasting large task binary with size 1098.5 KiB
# 25/06/11 20:22:27 WARN DAGScheduler: Broadcasting large task binary with size 1099.1 KiB
# 25/06/11 20:22:28 WARN DAGScheduler: Broadcasting large task binary with size 1099.5 KiB
# 25/06/11 20:22:28 WARN DAGScheduler: Broadcasting large task binary with size 1100.0 KiB
# 25/06/11 20:22:28 WARN DAGScheduler: Broadcasting large task binary with size 1100.5 KiB
# 25/06/11 20:22:28 WARN DAGScheduler: Broadcasting large task binary with size 1101.2 KiB
# 25/06/11 20:22:28 WARN DAGScheduler: Broadcasting large task binary with size 1102.5 KiB
# 25/06/11 20:22:28 WARN DAGScheduler: Broadcasting large task binary with size 1112.6 KiB
# 25/06/11 20:22:28 WARN DAGScheduler: Broadcasting large task binary with size 1113.1 KiB
# 25/06/11 20:22:28 WARN DAGScheduler: Broadcasting large task binary with size 1113.5 KiB
# 25/06/11 20:22:29 WARN DAGScheduler: Broadcasting large task binary with size 1114.1 KiB
# 25/06/11 20:22:29 WARN DAGScheduler: Broadcasting large task binary with size 1114.6 KiB
# 25/06/11 20:22:29 WARN DAGScheduler: Broadcasting large task binary with size 1115.3 KiB
# 25/06/11 20:22:29 WARN DAGScheduler: Broadcasting large task binary with size 1116.2 KiB
# 25/06/11 20:22:29 WARN DAGScheduler: Broadcasting large task binary with size 1125.6 KiB
# 25/06/11 20:22:29 WARN DAGScheduler: Broadcasting large task binary with size 1126.1 KiB
# 25/06/11 20:22:29 WARN DAGScheduler: Broadcasting large task binary with size 1126.5 KiB
# 25/06/11 20:22:29 WARN DAGScheduler: Broadcasting large task binary with size 1127.0 KiB
# 25/06/11 20:22:29 WARN DAGScheduler: Broadcasting large task binary with size 1127.5 KiB
# 25/06/11 20:22:29 WARN DAGScheduler: Broadcasting large task binary with size 1128.2 KiB
# 25/06/11 20:22:30 WARN DAGScheduler: Broadcasting large task binary with size 1129.4 KiB
# 25/06/11 20:22:30 WARN DAGScheduler: Broadcasting large task binary with size 1139.5 KiB
# 25/06/11 20:22:30 WARN DAGScheduler: Broadcasting large task binary with size 1140.1 KiB
# 25/06/11 20:22:30 WARN DAGScheduler: Broadcasting large task binary with size 1140.5 KiB
# 25/06/11 20:22:30 WARN DAGScheduler: Broadcasting large task binary with size 1141.0 KiB
# 25/06/11 20:22:30 WARN DAGScheduler: Broadcasting large task binary with size 1141.5 KiB
# 25/06/11 20:22:30 WARN DAGScheduler: Broadcasting large task binary with size 1142.2 KiB
# 25/06/11 20:22:30 WARN DAGScheduler: Broadcasting large task binary with size 1143.3 KiB
# 25/06/11 20:22:30 WARN DAGScheduler: Broadcasting large task binary with size 1152.8 KiB
# 25/06/11 20:22:31 WARN DAGScheduler: Broadcasting large task binary with size 1153.4 KiB
# 25/06/11 20:22:31 WARN DAGScheduler: Broadcasting large task binary with size 1153.8 KiB
# 25/06/11 20:22:31 WARN DAGScheduler: Broadcasting large task binary with size 1154.2 KiB
# 25/06/11 20:22:31 WARN DAGScheduler: Broadcasting large task binary with size 1154.8 KiB
# 25/06/11 20:22:31 WARN DAGScheduler: Broadcasting large task binary with size 1155.5 KiB
# 25/06/11 20:22:31 WARN DAGScheduler: Broadcasting large task binary with size 1156.8 KiB
# 25/06/11 20:22:31 WARN DAGScheduler: Broadcasting large task binary with size 1167.1 KiB
# 25/06/11 20:22:32 WARN DAGScheduler: Broadcasting large task binary with size 1167.6 KiB
# 25/06/11 20:22:32 WARN DAGScheduler: Broadcasting large task binary with size 1168.0 KiB
# 25/06/11 20:22:32 WARN DAGScheduler: Broadcasting large task binary with size 1168.5 KiB
# 25/06/11 20:22:32 WARN DAGScheduler: Broadcasting large task binary with size 1169.0 KiB
# 25/06/11 20:22:32 WARN DAGScheduler: Broadcasting large task binary with size 1169.8 KiB
# 25/06/11 20:22:32 WARN DAGScheduler: Broadcasting large task binary with size 1171.0 KiB
# 25/06/11 20:22:32 WARN DAGScheduler: Broadcasting large task binary with size 1181.9 KiB
# 25/06/11 20:22:32 WARN DAGScheduler: Broadcasting large task binary with size 1182.5 KiB
# 25/06/11 20:22:33 WARN DAGScheduler: Broadcasting large task binary with size 1182.9 KiB
# 25/06/11 20:22:33 WARN DAGScheduler: Broadcasting large task binary with size 1183.3 KiB
# 25/06/11 20:22:33 WARN DAGScheduler: Broadcasting large task binary with size 1183.9 KiB
# 25/06/11 20:22:33 WARN DAGScheduler: Broadcasting large task binary with size 1184.6 KiB
# 25/06/11 20:22:33 WARN DAGScheduler: Broadcasting large task binary with size 1185.6 KiB
# 25/06/11 20:22:33 WARN DAGScheduler: Broadcasting large task binary with size 1195.7 KiB
# 25/06/11 20:22:33 WARN DAGScheduler: Broadcasting large task binary with size 1196.2 KiB
# 25/06/11 20:22:33 WARN DAGScheduler: Broadcasting large task binary with size 1196.6 KiB
# 25/06/11 20:22:33 WARN DAGScheduler: Broadcasting large task binary with size 1197.1 KiB
# 25/06/11 20:22:34 WARN DAGScheduler: Broadcasting large task binary with size 1197.7 KiB
# 25/06/11 20:22:34 WARN DAGScheduler: Broadcasting large task binary with size 1198.3 KiB
# 25/06/11 20:22:34 WARN DAGScheduler: Broadcasting large task binary with size 1199.5 KiB
# 25/06/11 20:22:34 WARN DAGScheduler: Broadcasting large task binary with size 1209.9 KiB
# 25/06/11 20:22:34 WARN DAGScheduler: Broadcasting large task binary with size 1210.4 KiB
# 25/06/11 20:22:34 WARN DAGScheduler: Broadcasting large task binary with size 1210.8 KiB
# 25/06/11 20:22:35 WARN DAGScheduler: Broadcasting large task binary with size 1211.3 KiB
# 25/06/11 20:22:35 WARN DAGScheduler: Broadcasting large task binary with size 1211.8 KiB
# 25/06/11 20:22:35 WARN DAGScheduler: Broadcasting large task binary with size 1212.5 KiB
# 25/06/11 20:22:35 WARN DAGScheduler: Broadcasting large task binary with size 1213.5 KiB
# 25/06/11 20:22:35 WARN DAGScheduler: Broadcasting large task binary with size 1223.3 KiB
# 25/06/11 20:22:35 WARN DAGScheduler: Broadcasting large task binary with size 1223.8 KiB
# 25/06/11 20:22:35 WARN DAGScheduler: Broadcasting large task binary with size 1224.2 KiB
# 25/06/11 20:22:35 WARN DAGScheduler: Broadcasting large task binary with size 1224.7 KiB
# 25/06/11 20:22:35 WARN DAGScheduler: Broadcasting large task binary with size 1225.3 KiB
# 25/06/11 20:22:36 WARN DAGScheduler: Broadcasting large task binary with size 1226.1 KiB
# 25/06/11 20:22:36 WARN DAGScheduler: Broadcasting large task binary with size 1227.2 KiB
# 25/06/11 20:22:36 WARN DAGScheduler: Broadcasting large task binary with size 1238.4 KiB
# 25/06/11 20:22:36 WARN DAGScheduler: Broadcasting large task binary with size 1239.0 KiB
# 25/06/11 20:22:36 WARN DAGScheduler: Broadcasting large task binary with size 1239.4 KiB
# 25/06/11 20:22:36 WARN DAGScheduler: Broadcasting large task binary with size 1239.8 KiB
# 25/06/11 20:22:36 WARN DAGScheduler: Broadcasting large task binary with size 1240.3 KiB
# 25/06/11 20:22:36 WARN DAGScheduler: Broadcasting large task binary with size 1241.1 KiB
# 25/06/11 20:22:36 WARN DAGScheduler: Broadcasting large task binary with size 1242.2 KiB
# 25/06/11 20:22:36 WARN DAGScheduler: Broadcasting large task binary with size 1251.8 KiB
# 25/06/11 20:22:37 WARN DAGScheduler: Broadcasting large task binary with size 1252.3 KiB
# 25/06/11 20:22:37 WARN DAGScheduler: Broadcasting large task binary with size 1252.7 KiB
# 25/06/11 20:22:37 WARN DAGScheduler: Broadcasting large task binary with size 1253.1 KiB
# 25/06/11 20:22:37 WARN DAGScheduler: Broadcasting large task binary with size 1253.7 KiB
# 25/06/11 20:22:37 WARN DAGScheduler: Broadcasting large task binary with size 1254.4 KiB
# 25/06/11 20:22:37 WARN DAGScheduler: Broadcasting large task binary with size 1255.4 KiB
# 25/06/11 20:22:37 WARN DAGScheduler: Broadcasting large task binary with size 1265.2 KiB
# 25/06/11 20:22:37 WARN DAGScheduler: Broadcasting large task binary with size 1265.8 KiB
# 25/06/11 20:22:37 WARN DAGScheduler: Broadcasting large task binary with size 1266.2 KiB
# 25/06/11 20:22:37 WARN DAGScheduler: Broadcasting large task binary with size 1266.6 KiB
# 25/06/11 20:22:38 WARN DAGScheduler: Broadcasting large task binary with size 1267.1 KiB
# 25/06/11 20:22:38 WARN DAGScheduler: Broadcasting large task binary with size 1267.9 KiB
# 25/06/11 20:22:38 WARN DAGScheduler: Broadcasting large task binary with size 1269.0 KiB
# 25/06/11 20:22:38 WARN DAGScheduler: Broadcasting large task binary with size 1279.5 KiB
# 25/06/11 20:22:38 WARN DAGScheduler: Broadcasting large task binary with size 1280.1 KiB
# 25/06/11 20:22:38 WARN DAGScheduler: Broadcasting large task binary with size 1280.5 KiB
# 25/06/11 20:22:38 WARN DAGScheduler: Broadcasting large task binary with size 1280.9 KiB
# 25/06/11 20:22:38 WARN DAGScheduler: Broadcasting large task binary with size 1281.5 KiB
# 25/06/11 20:22:38 WARN DAGScheduler: Broadcasting large task binary with size 1282.1 KiB
# 25/06/11 20:22:38 WARN DAGScheduler: Broadcasting large task binary with size 1283.1 KiB
# 25/06/11 20:22:39 WARN DAGScheduler: Broadcasting large task binary with size 1293.1 KiB
# 25/06/11 20:22:39 WARN DAGScheduler: Broadcasting large task binary with size 1293.7 KiB
# 25/06/11 20:22:39 WARN DAGScheduler: Broadcasting large task binary with size 1294.1 KiB
# 25/06/11 20:22:39 WARN DAGScheduler: Broadcasting large task binary with size 1294.5 KiB
# 25/06/11 20:22:39 WARN DAGScheduler: Broadcasting large task binary with size 1295.1 KiB
# 25/06/11 20:22:39 WARN DAGScheduler: Broadcasting large task binary with size 1295.9 KiB
# 25/06/11 20:22:39 WARN DAGScheduler: Broadcasting large task binary with size 1297.0 KiB
# 25/06/11 20:22:39 WARN DAGScheduler: Broadcasting large task binary with size 1307.2 KiB
# 25/06/11 20:22:39 WARN DAGScheduler: Broadcasting large task binary with size 1307.8 KiB
# 25/06/11 20:22:40 WARN DAGScheduler: Broadcasting large task binary with size 1308.2 KiB
# 25/06/11 20:22:40 WARN DAGScheduler: Broadcasting large task binary with size 1308.6 KiB
# 25/06/11 20:22:40 WARN DAGScheduler: Broadcasting large task binary with size 1309.2 KiB
# 25/06/11 20:22:40 WARN DAGScheduler: Broadcasting large task binary with size 1309.9 KiB
# 25/06/11 20:22:40 WARN DAGScheduler: Broadcasting large task binary with size 1311.0 KiB
# 25/06/11 20:22:40 WARN DAGScheduler: Broadcasting large task binary with size 1321.3 KiB
# 25/06/11 20:22:40 WARN DAGScheduler: Broadcasting large task binary with size 1321.8 KiB
# 25/06/11 20:22:40 WARN DAGScheduler: Broadcasting large task binary with size 1322.2 KiB
# 25/06/11 20:22:40 WARN DAGScheduler: Broadcasting large task binary with size 1322.7 KiB
# 25/06/11 20:22:41 WARN DAGScheduler: Broadcasting large task binary with size 1323.2 KiB
# 25/06/11 20:22:41 WARN DAGScheduler: Broadcasting large task binary with size 1324.0 KiB
# 25/06/11 20:22:41 WARN DAGScheduler: Broadcasting large task binary with size 1325.1 KiB
# 25/06/11 20:22:41 WARN DAGScheduler: Broadcasting large task binary with size 1335.5 KiB
# 25/06/11 20:22:41 WARN DAGScheduler: Broadcasting large task binary with size 1336.0 KiB
# 25/06/11 20:22:41 WARN DAGScheduler: Broadcasting large task binary with size 1336.4 KiB
# 25/06/11 20:22:41 WARN DAGScheduler: Broadcasting large task binary with size 1336.9 KiB
# 25/06/11 20:22:41 WARN DAGScheduler: Broadcasting large task binary with size 1337.4 KiB
# 25/06/11 20:22:41 WARN DAGScheduler: Broadcasting large task binary with size 1338.1 KiB
# 25/06/11 20:22:41 WARN DAGScheduler: Broadcasting large task binary with size 1339.1 KiB
# 25/06/11 20:22:42 WARN DAGScheduler: Broadcasting large task binary with size 1349.0 KiB
# 25/06/11 20:22:42 WARN DAGScheduler: Broadcasting large task binary with size 1349.6 KiB
# 25/06/11 20:22:42 WARN DAGScheduler: Broadcasting large task binary with size 1350.0 KiB
# 25/06/11 20:22:42 WARN DAGScheduler: Broadcasting large task binary with size 1350.4 KiB
# 25/06/11 20:22:42 WARN DAGScheduler: Broadcasting large task binary with size 1351.1 KiB
# 25/06/11 20:22:42 WARN DAGScheduler: Broadcasting large task binary with size 1351.9 KiB
# 25/06/11 20:22:42 WARN DAGScheduler: Broadcasting large task binary with size 1353.1 KiB
# 25/06/11 20:22:42 WARN DAGScheduler: Broadcasting large task binary with size 1364.8 KiB
# 25/06/11 20:22:42 WARN DAGScheduler: Broadcasting large task binary with size 1365.4 KiB
# 25/06/11 20:22:43 WARN DAGScheduler: Broadcasting large task binary with size 1365.8 KiB
# 25/06/11 20:22:43 WARN DAGScheduler: Broadcasting large task binary with size 1366.2 KiB
# 25/06/11 20:22:43 WARN DAGScheduler: Broadcasting large task binary with size 1366.8 KiB
# 25/06/11 20:22:43 WARN DAGScheduler: Broadcasting large task binary with size 1367.5 KiB
# 25/06/11 20:22:43 WARN DAGScheduler: Broadcasting large task binary with size 1368.7 KiB
# 25/06/11 20:22:43 WARN DAGScheduler: Broadcasting large task binary with size 1379.2 KiB
# 25/06/11 20:22:43 WARN DAGScheduler: Broadcasting large task binary with size 1379.7 KiB
# 25/06/11 20:22:43 WARN DAGScheduler: Broadcasting large task binary with size 1380.1 KiB
# 25/06/11 20:22:43 WARN DAGScheduler: Broadcasting large task binary with size 1380.6 KiB
# 25/06/11 20:22:44 WARN DAGScheduler: Broadcasting large task binary with size 1381.1 KiB
# 25/06/11 20:22:44 WARN DAGScheduler: Broadcasting large task binary with size 1381.8 KiB
# 25/06/11 20:22:44 WARN DAGScheduler: Broadcasting large task binary with size 1383.0 KiB
# 25/06/11 20:22:44 WARN DAGScheduler: Broadcasting large task binary with size 1393.3 KiB
# 25/06/11 20:22:44 WARN DAGScheduler: Broadcasting large task binary with size 1393.9 KiB
# 25/06/11 20:22:44 WARN DAGScheduler: Broadcasting large task binary with size 1394.3 KiB
# 25/06/11 20:22:44 WARN DAGScheduler: Broadcasting large task binary with size 1394.7 KiB
# 25/06/11 20:22:44 WARN DAGScheduler: Broadcasting large task binary with size 1395.2 KiB
# 25/06/11 20:22:44 WARN DAGScheduler: Broadcasting large task binary with size 1395.9 KiB
# 25/06/11 20:22:44 WARN DAGScheduler: Broadcasting large task binary with size 1397.1 KiB
# 25/06/11 20:22:45 WARN DAGScheduler: Broadcasting large task binary with size 1407.3 KiB
# 25/06/11 20:22:45 WARN DAGScheduler: Broadcasting large task binary with size 1407.8 KiB
# 25/06/11 20:22:45 WARN DAGScheduler: Broadcasting large task binary with size 1408.3 KiB
# 25/06/11 20:22:45 WARN DAGScheduler: Broadcasting large task binary with size 1408.7 KiB
# 25/06/11 20:22:45 WARN DAGScheduler: Broadcasting large task binary with size 1409.2 KiB
# 25/06/11 20:22:45 WARN DAGScheduler: Broadcasting large task binary with size 1409.9 KiB
# 25/06/11 20:22:45 WARN DAGScheduler: Broadcasting large task binary with size 1411.1 KiB
# 25/06/11 20:22:45 WARN DAGScheduler: Broadcasting large task binary with size 1421.5 KiB
# 25/06/11 20:22:45 WARN DAGScheduler: Broadcasting large task binary with size 1422.0 KiB
# 25/06/11 20:22:46 WARN DAGScheduler: Broadcasting large task binary with size 1422.4 KiB
# 25/06/11 20:22:46 WARN DAGScheduler: Broadcasting large task binary with size 1422.9 KiB
# 25/06/11 20:22:46 WARN DAGScheduler: Broadcasting large task binary with size 1423.5 KiB
# 25/06/11 20:22:46 WARN DAGScheduler: Broadcasting large task binary with size 1424.1 KiB
# 25/06/11 20:22:46 WARN DAGScheduler: Broadcasting large task binary with size 1425.1 KiB
# 25/06/11 20:22:46 WARN DAGScheduler: Broadcasting large task binary with size 1434.9 KiB
# 25/06/11 20:22:46 WARN DAGScheduler: Broadcasting large task binary with size 1435.5 KiB
# 25/06/11 20:22:46 WARN DAGScheduler: Broadcasting large task binary with size 1435.9 KiB
# 25/06/11 20:22:46 WARN DAGScheduler: Broadcasting large task binary with size 1436.4 KiB
# 25/06/11 20:22:47 WARN DAGScheduler: Broadcasting large task binary with size 1436.9 KiB
# 25/06/11 20:22:47 WARN DAGScheduler: Broadcasting large task binary with size 1437.7 KiB
# 25/06/11 20:22:47 WARN DAGScheduler: Broadcasting large task binary with size 1438.6 KiB
# 25/06/11 20:22:47 WARN DAGScheduler: Broadcasting large task binary with size 1447.9 KiB
# 25/06/11 20:22:47 WARN DAGScheduler: Broadcasting large task binary with size 1448.5 KiB
# 25/06/11 20:22:47 WARN DAGScheduler: Broadcasting large task binary with size 1448.9 KiB
# 25/06/11 20:22:47 WARN DAGScheduler: Broadcasting large task binary with size 1449.4 KiB
# 25/06/11 20:22:47 WARN DAGScheduler: Broadcasting large task binary with size 1449.9 KiB
# 25/06/11 20:22:47 WARN DAGScheduler: Broadcasting large task binary with size 1450.7 KiB
# 25/06/11 20:22:48 WARN DAGScheduler: Broadcasting large task binary with size 1451.7 KiB
# 25/06/11 20:22:48 WARN DAGScheduler: Broadcasting large task binary with size 1462.3 KiB
# 25/06/11 20:22:48 WARN DAGScheduler: Broadcasting large task binary with size 1462.9 KiB
# 25/06/11 20:22:48 WARN DAGScheduler: Broadcasting large task binary with size 1463.3 KiB
# 25/06/11 20:22:48 WARN DAGScheduler: Broadcasting large task binary with size 1463.8 KiB
# 25/06/11 20:22:48 WARN DAGScheduler: Broadcasting large task binary with size 1464.2 KiB
# 25/06/11 20:22:48 WARN DAGScheduler: Broadcasting large task binary with size 1464.9 KiB
# 25/06/11 20:22:48 WARN DAGScheduler: Broadcasting large task binary with size 1466.0 KiB
# 25/06/11 20:22:48 WARN DAGScheduler: Broadcasting large task binary with size 1476.4 KiB
# 25/06/11 20:22:49 WARN DAGScheduler: Broadcasting large task binary with size 1477.0 KiB
# 25/06/11 20:22:49 WARN DAGScheduler: Broadcasting large task binary with size 1477.4 KiB
# 25/06/11 20:22:49 WARN DAGScheduler: Broadcasting large task binary with size 1477.8 KiB
# 25/06/11 20:22:49 WARN DAGScheduler: Broadcasting large task binary with size 1478.3 KiB
# 25/06/11 20:22:49 WARN DAGScheduler: Broadcasting large task binary with size 1479.2 KiB
# 25/06/11 20:22:49 WARN DAGScheduler: Broadcasting large task binary with size 1480.3 KiB
# 25/06/11 20:22:49 WARN DAGScheduler: Broadcasting large task binary with size 1490.3 KiB
# 25/06/11 20:22:49 WARN DAGScheduler: Broadcasting large task binary with size 1490.9 KiB
# 25/06/11 20:22:49 WARN DAGScheduler: Broadcasting large task binary with size 1491.3 KiB
# 25/06/11 20:22:49 WARN DAGScheduler: Broadcasting large task binary with size 1491.8 KiB
# 25/06/11 20:22:50 WARN DAGScheduler: Broadcasting large task binary with size 1492.3 KiB
# 25/06/11 20:22:50 WARN DAGScheduler: Broadcasting large task binary with size 1493.0 KiB
# 25/06/11 20:22:50 WARN DAGScheduler: Broadcasting large task binary with size 1494.1 KiB
# 25/06/11 20:22:50 WARN DAGScheduler: Broadcasting large task binary with size 1504.1 KiB
# 25/06/11 20:22:50 WARN DAGScheduler: Broadcasting large task binary with size 1504.7 KiB
# 25/06/11 20:22:50 WARN DAGScheduler: Broadcasting large task binary with size 1505.1 KiB
# 25/06/11 20:22:50 WARN DAGScheduler: Broadcasting large task binary with size 1505.6 KiB
# 25/06/11 20:22:50 WARN DAGScheduler: Broadcasting large task binary with size 1506.1 KiB
# 25/06/11 20:22:50 WARN DAGScheduler: Broadcasting large task binary with size 1507.1 KiB
# 25/06/11 20:22:51 WARN DAGScheduler: Broadcasting large task binary with size 1508.2 KiB
# 25/06/11 20:22:51 WARN DAGScheduler: Broadcasting large task binary with size 1518.9 KiB
# 25/06/11 20:22:51 WARN DAGScheduler: Broadcasting large task binary with size 1519.5 KiB
# 25/06/11 20:22:51 WARN DAGScheduler: Broadcasting large task binary with size 1519.9 KiB
# 25/06/11 20:22:51 WARN DAGScheduler: Broadcasting large task binary with size 1520.3 KiB
# 25/06/11 20:22:51 WARN DAGScheduler: Broadcasting large task binary with size 1520.9 KiB
# 25/06/11 20:22:51 WARN DAGScheduler: Broadcasting large task binary with size 1521.7 KiB
# 25/06/11 20:22:51 WARN DAGScheduler: Broadcasting large task binary with size 1522.8 KiB
# 25/06/11 20:22:51 WARN DAGScheduler: Broadcasting large task binary with size 1532.4 KiB
# 25/06/11 20:22:52 WARN DAGScheduler: Broadcasting large task binary with size 1533.0 KiB
# 25/06/11 20:22:52 WARN DAGScheduler: Broadcasting large task binary with size 1533.4 KiB
# 25/06/11 20:22:52 WARN DAGScheduler: Broadcasting large task binary with size 1533.8 KiB
# 25/06/11 20:22:52 WARN DAGScheduler: Broadcasting large task binary with size 1534.5 KiB
# 25/06/11 20:22:52 WARN DAGScheduler: Broadcasting large task binary with size 1535.2 KiB
# 25/06/11 20:22:52 WARN DAGScheduler: Broadcasting large task binary with size 1536.1 KiB
# 25/06/11 20:22:52 WARN DAGScheduler: Broadcasting large task binary with size 1545.2 KiB
# 25/06/11 20:22:52 WARN DAGScheduler: Broadcasting large task binary with size 1545.7 KiB
# 25/06/11 20:22:52 WARN DAGScheduler: Broadcasting large task binary with size 1546.1 KiB
# 25/06/11 20:22:53 WARN DAGScheduler: Broadcasting large task binary with size 1546.6 KiB
# 25/06/11 20:22:53 WARN DAGScheduler: Broadcasting large task binary with size 1547.1 KiB
# 25/06/11 20:22:53 WARN DAGScheduler: Broadcasting large task binary with size 1547.9 KiB
# 25/06/11 20:22:53 WARN DAGScheduler: Broadcasting large task binary with size 1549.2 KiB
# 25/06/11 20:22:53 WARN DAGScheduler: Broadcasting large task binary with size 1559.8 KiB
# 25/06/11 20:22:53 WARN DAGScheduler: Broadcasting large task binary with size 1560.4 KiB
# 25/06/11 20:22:53 WARN DAGScheduler: Broadcasting large task binary with size 1560.8 KiB
# 25/06/11 20:22:53 WARN DAGScheduler: Broadcasting large task binary with size 1561.3 KiB
# 25/06/11 20:22:53 WARN DAGScheduler: Broadcasting large task binary with size 1561.8 KiB
# 25/06/11 20:22:54 WARN DAGScheduler: Broadcasting large task binary with size 1562.5 KiB
# 25/06/11 20:22:54 WARN DAGScheduler: Broadcasting large task binary with size 1563.7 KiB
# 25/06/11 20:22:54 WARN DAGScheduler: Broadcasting large task binary with size 1574.1 KiB
# 25/06/11 20:22:54 WARN DAGScheduler: Broadcasting large task binary with size 1574.7 KiB
# 25/06/11 20:22:54 WARN DAGScheduler: Broadcasting large task binary with size 1575.1 KiB
# 25/06/11 20:22:54 WARN DAGScheduler: Broadcasting large task binary with size 1575.6 KiB
# 25/06/11 20:22:54 WARN DAGScheduler: Broadcasting large task binary with size 1576.1 KiB
# 25/06/11 20:22:54 WARN DAGScheduler: Broadcasting large task binary with size 1576.8 KiB
# 25/06/11 20:22:54 WARN DAGScheduler: Broadcasting large task binary with size 1578.0 KiB
# 25/06/11 20:22:55 WARN DAGScheduler: Broadcasting large task binary with size 1588.2 KiB
# 25/06/11 20:22:55 WARN DAGScheduler: Broadcasting large task binary with size 1588.8 KiB
# 25/06/11 20:22:55 WARN DAGScheduler: Broadcasting large task binary with size 1589.2 KiB
# 25/06/11 20:22:55 WARN DAGScheduler: Broadcasting large task binary with size 1589.7 KiB
# 25/06/11 20:22:55 WARN DAGScheduler: Broadcasting large task binary with size 1590.3 KiB
# 25/06/11 20:22:55 WARN DAGScheduler: Broadcasting large task binary with size 1591.0 KiB
# 25/06/11 20:22:55 WARN DAGScheduler: Broadcasting large task binary with size 1592.2 KiB
# 25/06/11 20:22:55 WARN DAGScheduler: Broadcasting large task binary with size 1602.7 KiB
# 25/06/11 20:22:55 WARN DAGScheduler: Broadcasting large task binary with size 1603.3 KiB
# 25/06/11 20:22:56 WARN DAGScheduler: Broadcasting large task binary with size 1603.7 KiB
# 25/06/11 20:22:56 WARN DAGScheduler: Broadcasting large task binary with size 1604.2 KiB
# 25/06/11 20:22:56 WARN DAGScheduler: Broadcasting large task binary with size 1604.7 KiB
# 25/06/11 20:22:56 WARN DAGScheduler: Broadcasting large task binary with size 1605.5 KiB
# 25/06/11 20:22:56 WARN DAGScheduler: Broadcasting large task binary with size 1606.6 KiB
# 25/06/11 20:22:56 WARN DAGScheduler: Broadcasting large task binary with size 1617.4 KiB
# 25/06/11 20:22:56 WARN DAGScheduler: Broadcasting large task binary with size 1618.0 KiB
# 25/06/11 20:22:56 WARN DAGScheduler: Broadcasting large task binary with size 1618.4 KiB
# 25/06/11 20:22:56 WARN DAGScheduler: Broadcasting large task binary with size 1618.9 KiB
# 25/06/11 20:22:57 WARN DAGScheduler: Broadcasting large task binary with size 1619.4 KiB
# 25/06/11 20:22:57 WARN DAGScheduler: Broadcasting large task binary with size 1620.2 KiB
# 25/06/11 20:22:57 WARN DAGScheduler: Broadcasting large task binary with size 1621.2 KiB
# 25/06/11 20:22:57 WARN DAGScheduler: Broadcasting large task binary with size 1631.6 KiB
# 25/06/11 20:22:57 WARN DAGScheduler: Broadcasting large task binary with size 1632.2 KiB
# 25/06/11 20:22:57 WARN DAGScheduler: Broadcasting large task binary with size 1632.6 KiB
# 25/06/11 20:22:57 WARN DAGScheduler: Broadcasting large task binary with size 1633.1 KiB
# 25/06/11 20:22:57 WARN DAGScheduler: Broadcasting large task binary with size 1633.7 KiB
# 25/06/11 20:22:57 WARN DAGScheduler: Broadcasting large task binary with size 1634.4 KiB
# 25/06/11 20:22:58 WARN DAGScheduler: Broadcasting large task binary with size 1635.7 KiB
# 25/06/11 20:22:58 WARN DAGScheduler: Broadcasting large task binary with size 1646.0 KiB
# 25/06/11 20:22:58 WARN DAGScheduler: Broadcasting large task binary with size 1646.6 KiB
# 25/06/11 20:22:58 WARN DAGScheduler: Broadcasting large task binary with size 1647.0 KiB
# 25/06/11 20:22:58 WARN DAGScheduler: Broadcasting large task binary with size 1647.5 KiB
# 25/06/11 20:22:58 WARN DAGScheduler: Broadcasting large task binary with size 1648.0 KiB
# 25/06/11 20:22:58 WARN DAGScheduler: Broadcasting large task binary with size 1648.7 KiB
# 25/06/11 20:22:58 WARN DAGScheduler: Broadcasting large task binary with size 1649.9 KiB
# 25/06/11 20:22:59 WARN DAGScheduler: Broadcasting large task binary with size 1660.5 KiB
# 25/06/11 20:22:59 WARN DAGScheduler: Broadcasting large task binary with size 1661.1 KiB
# 25/06/11 20:22:59 WARN DAGScheduler: Broadcasting large task binary with size 1661.5 KiB
# 25/06/11 20:22:59 WARN DAGScheduler: Broadcasting large task binary with size 1662.0 KiB
# 25/06/11 20:22:59 WARN DAGScheduler: Broadcasting large task binary with size 1662.6 KiB
# 25/06/11 20:22:59 WARN DAGScheduler: Broadcasting large task binary with size 1663.3 KiB
# 25/06/11 20:22:59 WARN DAGScheduler: Broadcasting large task binary with size 1664.3 KiB
# 25/06/11 20:22:59 WARN DAGScheduler: Broadcasting large task binary with size 1674.8 KiB
# 25/06/11 20:22:59 WARN DAGScheduler: Broadcasting large task binary with size 1675.4 KiB
# 25/06/11 20:23:00 WARN DAGScheduler: Broadcasting large task binary with size 1675.8 KiB
# 25/06/11 20:23:00 WARN DAGScheduler: Broadcasting large task binary with size 1676.3 KiB
# 25/06/11 20:23:00 WARN DAGScheduler: Broadcasting large task binary with size 1676.8 KiB
# 25/06/11 20:23:00 WARN DAGScheduler: Broadcasting large task binary with size 1677.5 KiB
# 25/06/11 20:23:00 WARN DAGScheduler: Broadcasting large task binary with size 1678.5 KiB
# 25/06/11 20:23:00 WARN DAGScheduler: Broadcasting large task binary with size 1688.6 KiB
# 25/06/11 20:23:00 WARN DAGScheduler: Broadcasting large task binary with size 1689.2 KiB
# 25/06/11 20:23:00 WARN DAGScheduler: Broadcasting large task binary with size 1689.6 KiB
# 25/06/11 20:23:00 WARN DAGScheduler: Broadcasting large task binary with size 1690.1 KiB
# 25/06/11 20:23:01 WARN DAGScheduler: Broadcasting large task binary with size 1690.6 KiB
# 25/06/11 20:23:01 WARN DAGScheduler: Broadcasting large task binary with size 1691.4 KiB
# 25/06/11 20:23:01 WARN DAGScheduler: Broadcasting large task binary with size 1692.7 KiB
# 25/06/11 20:23:01 WARN DAGScheduler: Broadcasting large task binary with size 1703.0 KiB
# 25/06/11 20:23:01 WARN DAGScheduler: Broadcasting large task binary with size 1703.5 KiB
# 25/06/11 20:23:01 WARN DAGScheduler: Broadcasting large task binary with size 1703.9 KiB
# 25/06/11 20:23:01 WARN DAGScheduler: Broadcasting large task binary with size 1704.5 KiB
# 25/06/11 20:23:01 WARN DAGScheduler: Broadcasting large task binary with size 1705.0 KiB
# 25/06/11 20:23:02 WARN DAGScheduler: Broadcasting large task binary with size 1705.7 KiB
# 25/06/11 20:23:02 WARN DAGScheduler: Broadcasting large task binary with size 1706.7 KiB
# 25/06/11 20:23:02 WARN DAGScheduler: Broadcasting large task binary with size 1716.6 KiB
# 25/06/11 20:23:02 WARN DAGScheduler: Broadcasting large task binary with size 1717.2 KiB
# 25/06/11 20:23:02 WARN DAGScheduler: Broadcasting large task binary with size 1717.6 KiB
# 25/06/11 20:23:02 WARN DAGScheduler: Broadcasting large task binary with size 1718.1 KiB
# 25/06/11 20:23:02 WARN DAGScheduler: Broadcasting large task binary with size 1718.6 KiB
# 25/06/11 20:23:02 WARN DAGScheduler: Broadcasting large task binary with size 1719.3 KiB
# 25/06/11 20:23:02 WARN DAGScheduler: Broadcasting large task binary with size 1720.3 KiB
# 25/06/11 20:23:03 WARN DAGScheduler: Broadcasting large task binary with size 1730.8 KiB
# 25/06/11 20:23:03 WARN DAGScheduler: Broadcasting large task binary with size 1731.4 KiB
# 25/06/11 20:23:03 WARN DAGScheduler: Broadcasting large task binary with size 1731.8 KiB
# 25/06/11 20:23:03 WARN DAGScheduler: Broadcasting large task binary with size 1732.3 KiB
# 25/06/11 20:23:03 WARN DAGScheduler: Broadcasting large task binary with size 1732.8 KiB
# 25/06/11 20:23:03 WARN DAGScheduler: Broadcasting large task binary with size 1733.5 KiB
# 25/06/11 20:23:03 WARN DAGScheduler: Broadcasting large task binary with size 1734.6 KiB
# 25/06/11 20:23:03 WARN DAGScheduler: Broadcasting large task binary with size 1745.2 KiB
# 25/06/11 20:23:04 WARN DAGScheduler: Broadcasting large task binary with size 1745.8 KiB
# 25/06/11 20:23:04 WARN DAGScheduler: Broadcasting large task binary with size 1746.2 KiB
# 25/06/11 20:23:04 WARN DAGScheduler: Broadcasting large task binary with size 1746.7 KiB
# 25/06/11 20:23:04 WARN DAGScheduler: Broadcasting large task binary with size 1747.2 KiB
# 25/06/11 20:23:04 WARN DAGScheduler: Broadcasting large task binary with size 1747.9 KiB
# 25/06/11 20:23:04 WARN DAGScheduler: Broadcasting large task binary with size 1748.9 KiB
# 25/06/11 20:23:04 WARN DAGScheduler: Broadcasting large task binary with size 1759.5 KiB
# 25/06/11 20:23:04 WARN DAGScheduler: Broadcasting large task binary with size 1760.1 KiB
# 25/06/11 20:23:04 WARN DAGScheduler: Broadcasting large task binary with size 1760.5 KiB
# 25/06/11 20:23:05 WARN DAGScheduler: Broadcasting large task binary with size 1760.9 KiB
# 25/06/11 20:23:05 WARN DAGScheduler: Broadcasting large task binary with size 1761.5 KiB
# 25/06/11 20:23:05 WARN DAGScheduler: Broadcasting large task binary with size 1762.2 KiB
# 25/06/11 20:23:05 WARN DAGScheduler: Broadcasting large task binary with size 1763.3 KiB
# 25/06/11 20:23:05 WARN DAGScheduler: Broadcasting large task binary with size 1774.0 KiB
# 25/06/11 20:23:05 WARN DAGScheduler: Broadcasting large task binary with size 1774.6 KiB
# 25/06/11 20:23:05 WARN DAGScheduler: Broadcasting large task binary with size 1775.0 KiB
# 25/06/11 20:23:05 WARN DAGScheduler: Broadcasting large task binary with size 1775.4 KiB
# 25/06/11 20:23:05 WARN DAGScheduler: Broadcasting large task binary with size 1776.0 KiB
# 25/06/11 20:23:06 WARN DAGScheduler: Broadcasting large task binary with size 1776.7 KiB
# 25/06/11 20:23:06 WARN DAGScheduler: Broadcasting large task binary with size 1777.8 KiB
# 25/06/11 20:23:06 WARN DAGScheduler: Broadcasting large task binary with size 1788.6 KiB
# 25/06/11 20:23:06 WARN DAGScheduler: Broadcasting large task binary with size 1789.1 KiB
# 25/06/11 20:23:06 WARN DAGScheduler: Broadcasting large task binary with size 1789.5 KiB
# 25/06/11 20:23:06 WARN DAGScheduler: Broadcasting large task binary with size 1790.0 KiB
# 25/06/11 20:23:06 WARN DAGScheduler: Broadcasting large task binary with size 1790.5 KiB
# 25/06/11 20:23:06 WARN DAGScheduler: Broadcasting large task binary with size 1791.3 KiB
# 25/06/11 20:23:07 WARN DAGScheduler: Broadcasting large task binary with size 1792.5 KiB
# 25/06/11 20:23:07 WARN DAGScheduler: Broadcasting large task binary with size 1803.3 KiB
# 25/06/11 20:23:07 WARN DAGScheduler: Broadcasting large task binary with size 1803.9 KiB
# 25/06/11 20:23:07 WARN DAGScheduler: Broadcasting large task binary with size 1804.3 KiB
# 25/06/11 20:23:07 WARN DAGScheduler: Broadcasting large task binary with size 1804.7 KiB
# 25/06/11 20:23:07 WARN DAGScheduler: Broadcasting large task binary with size 1805.3 KiB
# 25/06/11 20:23:07 WARN DAGScheduler: Broadcasting large task binary with size 1806.0 KiB
# 25/06/11 20:23:07 WARN DAGScheduler: Broadcasting large task binary with size 1807.2 KiB
# 25/06/11 20:23:08 WARN DAGScheduler: Broadcasting large task binary with size 1817.8 KiB
# 25/06/11 20:23:08 WARN DAGScheduler: Broadcasting large task binary with size 1818.3 KiB
# 25/06/11 20:23:08 WARN DAGScheduler: Broadcasting large task binary with size 1818.7 KiB
# 25/06/11 20:23:08 WARN DAGScheduler: Broadcasting large task binary with size 1819.3 KiB
# 25/06/11 20:23:08 WARN DAGScheduler: Broadcasting large task binary with size 1819.8 KiB
# 25/06/11 20:23:08 WARN DAGScheduler: Broadcasting large task binary with size 1820.6 KiB
# 25/06/11 20:23:08 WARN DAGScheduler: Broadcasting large task binary with size 1821.7 KiB
# 25/06/11 20:23:08 WARN DAGScheduler: Broadcasting large task binary with size 1832.7 KiB
# 25/06/11 20:23:09 WARN DAGScheduler: Broadcasting large task binary with size 1833.2 KiB
# 25/06/11 20:23:09 WARN DAGScheduler: Broadcasting large task binary with size 1833.6 KiB
# 25/06/11 20:23:09 WARN DAGScheduler: Broadcasting large task binary with size 1834.1 KiB
# 25/06/11 20:23:09 WARN DAGScheduler: Broadcasting large task binary with size 1834.6 KiB
# 25/06/11 20:23:09 WARN DAGScheduler: Broadcasting large task binary with size 1835.3 KiB
# 25/06/11 20:23:09 WARN DAGScheduler: Broadcasting large task binary with size 1836.5 KiB
# 25/06/11 20:23:09 WARN DAGScheduler: Broadcasting large task binary with size 1845.9 KiB
# 25/06/11 20:23:09 WARN DAGScheduler: Broadcasting large task binary with size 1846.5 KiB
# 25/06/11 20:23:09 WARN DAGScheduler: Broadcasting large task binary with size 1846.9 KiB
# 25/06/11 20:23:10 WARN DAGScheduler: Broadcasting large task binary with size 1847.4 KiB
# 25/06/11 20:23:10 WARN DAGScheduler: Broadcasting large task binary with size 1847.9 KiB
# 25/06/11 20:23:10 WARN DAGScheduler: Broadcasting large task binary with size 1848.6 KiB
# 25/06/11 20:23:10 WARN DAGScheduler: Broadcasting large task binary with size 1849.9 KiB
# 25/06/11 20:23:10 WARN DAGScheduler: Broadcasting large task binary with size 1859.4 KiB
# 25/06/11 20:23:10 WARN DAGScheduler: Broadcasting large task binary with size 1859.9 KiB
# 25/06/11 20:23:10 WARN DAGScheduler: Broadcasting large task binary with size 1860.3 KiB
# 25/06/11 20:23:10 WARN DAGScheduler: Broadcasting large task binary with size 1860.8 KiB
# 25/06/11 20:23:11 WARN DAGScheduler: Broadcasting large task binary with size 1861.4 KiB
# 25/06/11 20:23:11 WARN DAGScheduler: Broadcasting large task binary with size 1862.2 KiB
# 25/06/11 20:23:11 WARN DAGScheduler: Broadcasting large task binary with size 1863.4 KiB
# 25/06/11 20:23:11 WARN DAGScheduler: Broadcasting large task binary with size 1873.3 KiB
# 25/06/11 20:23:11 WARN DAGScheduler: Broadcasting large task binary with size 1873.8 KiB
# 25/06/11 20:23:11 WARN DAGScheduler: Broadcasting large task binary with size 1874.2 KiB
# 25/06/11 20:23:11 WARN DAGScheduler: Broadcasting large task binary with size 1874.7 KiB
# 25/06/11 20:23:11 WARN DAGScheduler: Broadcasting large task binary with size 1875.3 KiB
# 25/06/11 20:23:12 WARN DAGScheduler: Broadcasting large task binary with size 1875.9 KiB
# 25/06/11 20:23:12 WARN DAGScheduler: Broadcasting large task binary with size 1877.0 KiB
# 25/06/11 20:23:12 WARN DAGScheduler: Broadcasting large task binary with size 1887.3 KiB
# 25/06/11 20:23:12 WARN DAGScheduler: Broadcasting large task binary with size 1887.8 KiB
# 25/06/11 20:23:12 WARN DAGScheduler: Broadcasting large task binary with size 1888.2 KiB
# 25/06/11 20:23:12 WARN DAGScheduler: Broadcasting large task binary with size 1888.7 KiB
# 25/06/11 20:23:12 WARN DAGScheduler: Broadcasting large task binary with size 1889.4 KiB
# 25/06/11 20:23:12 WARN DAGScheduler: Broadcasting large task binary with size 1890.1 KiB
# 25/06/11 20:23:12 WARN DAGScheduler: Broadcasting large task binary with size 1891.4 KiB
# 25/06/11 20:23:13 WARN DAGScheduler: Broadcasting large task binary with size 1903.2 KiB
# 25/06/11 20:23:13 WARN DAGScheduler: Broadcasting large task binary with size 1903.8 KiB
# 25/06/11 20:23:13 WARN DAGScheduler: Broadcasting large task binary with size 1904.2 KiB
# 25/06/11 20:23:13 WARN DAGScheduler: Broadcasting large task binary with size 1904.7 KiB
# 25/06/11 20:23:13 WARN DAGScheduler: Broadcasting large task binary with size 1905.4 KiB
# 25/06/11 20:23:13 WARN DAGScheduler: Broadcasting large task binary with size 1906.1 KiB
# 25/06/11 20:23:13 WARN DAGScheduler: Broadcasting large task binary with size 1907.0 KiB
# 25/06/11 20:23:13 WARN DAGScheduler: Broadcasting large task binary with size 1915.5 KiB
# 25/06/11 20:23:14 WARN DAGScheduler: Broadcasting large task binary with size 1916.1 KiB
# 25/06/11 20:23:14 WARN DAGScheduler: Broadcasting large task binary with size 1916.5 KiB
# 25/06/11 20:23:14 WARN DAGScheduler: Broadcasting large task binary with size 1917.0 KiB
# 25/06/11 20:23:14 WARN DAGScheduler: Broadcasting large task binary with size 1917.5 KiB
# 25/06/11 20:23:14 WARN DAGScheduler: Broadcasting large task binary with size 1918.2 KiB
# 25/06/11 20:23:14 WARN DAGScheduler: Broadcasting large task binary with size 1919.1 KiB
# 25/06/11 20:23:14 WARN DAGScheduler: Broadcasting large task binary with size 1927.6 KiB
# 25/06/11 20:23:14 WARN DAGScheduler: Broadcasting large task binary with size 1928.2 KiB
# 25/06/11 20:23:15 WARN DAGScheduler: Broadcasting large task binary with size 1928.6 KiB
# 25/06/11 20:23:15 WARN DAGScheduler: Broadcasting large task binary with size 1929.1 KiB
# 25/06/11 20:23:15 WARN DAGScheduler: Broadcasting large task binary with size 1929.6 KiB
# 25/06/11 20:23:15 WARN DAGScheduler: Broadcasting large task binary with size 1930.3 KiB
# 25/06/11 20:23:15 WARN DAGScheduler: Broadcasting large task binary with size 1931.5 KiB
# 25/06/11 20:23:15 WARN DAGScheduler: Broadcasting large task binary with size 1941.5 KiB
# 25/06/11 20:23:15 WARN DAGScheduler: Broadcasting large task binary with size 1942.1 KiB
# 25/06/11 20:23:15 WARN DAGScheduler: Broadcasting large task binary with size 1942.5 KiB
# 25/06/11 20:23:16 WARN DAGScheduler: Broadcasting large task binary with size 1943.0 KiB
# 25/06/11 20:23:16 WARN DAGScheduler: Broadcasting large task binary with size 1943.5 KiB
# 25/06/11 20:23:16 WARN DAGScheduler: Broadcasting large task binary with size 1944.2 KiB
# 25/06/11 20:23:16 WARN DAGScheduler: Broadcasting large task binary with size 1945.4 KiB
# 25/06/11 20:23:16 WARN DAGScheduler: Broadcasting large task binary with size 1955.8 KiB
# 25/06/11 20:23:16 WARN DAGScheduler: Broadcasting large task binary with size 1956.4 KiB
# 25/06/11 20:23:16 WARN DAGScheduler: Broadcasting large task binary with size 1956.8 KiB
# 25/06/11 20:23:16 WARN DAGScheduler: Broadcasting large task binary with size 1957.2 KiB
# 25/06/11 20:23:17 WARN DAGScheduler: Broadcasting large task binary with size 1957.7 KiB
# 25/06/11 20:23:17 WARN DAGScheduler: Broadcasting large task binary with size 1958.5 KiB
# 25/06/11 20:23:17 WARN DAGScheduler: Broadcasting large task binary with size 1959.5 KiB
# 25/06/11 20:23:17 WARN DAGScheduler: Broadcasting large task binary with size 1968.4 KiB
# 25/06/11 20:23:17 WARN DAGScheduler: Broadcasting large task binary with size 1969.0 KiB
# 25/06/11 20:23:17 WARN DAGScheduler: Broadcasting large task binary with size 1969.4 KiB
# 25/06/11 20:23:17 WARN DAGScheduler: Broadcasting large task binary with size 1969.8 KiB
# 25/06/11 20:23:17 WARN DAGScheduler: Broadcasting large task binary with size 1970.4 KiB
# 25/06/11 20:23:18 WARN DAGScheduler: Broadcasting large task binary with size 1971.2 KiB
# 25/06/11 20:23:18 WARN DAGScheduler: Broadcasting large task binary with size 1972.4 KiB
# 25/06/11 20:23:18 WARN DAGScheduler: Broadcasting large task binary with size 1982.9 KiB
# 25/06/11 20:23:18 WARN DAGScheduler: Broadcasting large task binary with size 1983.5 KiB
# 25/06/11 20:23:18 WARN DAGScheduler: Broadcasting large task binary with size 1983.9 KiB
# 25/06/11 20:23:18 WARN DAGScheduler: Broadcasting large task binary with size 1984.3 KiB
# 25/06/11 20:23:18 WARN DAGScheduler: Broadcasting large task binary with size 1984.9 KiB
# 25/06/11 20:23:18 WARN DAGScheduler: Broadcasting large task binary with size 1985.6 KiB
# 25/06/11 20:23:18 WARN DAGScheduler: Broadcasting large task binary with size 1986.8 KiB
# 25/06/11 20:23:19 WARN DAGScheduler: Broadcasting large task binary with size 1997.5 KiB
# 25/06/11 20:23:19 WARN DAGScheduler: Broadcasting large task binary with size 1998.0 KiB
# 25/06/11 20:23:19 WARN DAGScheduler: Broadcasting large task binary with size 1998.4 KiB
# 25/06/11 20:23:19 WARN DAGScheduler: Broadcasting large task binary with size 1998.9 KiB
# 25/06/11 20:23:19 WARN DAGScheduler: Broadcasting large task binary with size 1999.5 KiB
# 25/06/11 20:23:19 WARN DAGScheduler: Broadcasting large task binary with size 2000.3 KiB
# 25/06/11 20:23:19 WARN DAGScheduler: Broadcasting large task binary with size 2001.5 KiB
# 25/06/11 20:23:20 WARN DAGScheduler: Broadcasting large task binary with size 2012.1 KiB
# 25/06/11 20:23:20 WARN DAGScheduler: Broadcasting large task binary with size 2012.6 KiB
# 25/06/11 20:23:20 WARN DAGScheduler: Broadcasting large task binary with size 2013.0 KiB
# 25/06/11 20:23:20 WARN DAGScheduler: Broadcasting large task binary with size 2013.5 KiB
# 25/06/11 20:23:20 WARN DAGScheduler: Broadcasting large task binary with size 2014.0 KiB
# 25/06/11 20:23:20 WARN DAGScheduler: Broadcasting large task binary with size 2015.0 KiB
# 25/06/11 20:23:20 WARN DAGScheduler: Broadcasting large task binary with size 2016.2 KiB
# 25/06/11 20:23:20 WARN DAGScheduler: Broadcasting large task binary with size 2027.9 KiB
# 25/06/11 20:23:21 WARN DAGScheduler: Broadcasting large task binary with size 2028.4 KiB
# 25/06/11 20:23:21 WARN DAGScheduler: Broadcasting large task binary with size 2028.8 KiB
# 25/06/11 20:23:21 WARN DAGScheduler: Broadcasting large task binary with size 2029.3 KiB
# 25/06/11 20:23:21 WARN DAGScheduler: Broadcasting large task binary with size 2029.8 KiB
# 25/06/11 20:23:21 WARN DAGScheduler: Broadcasting large task binary with size 2030.6 KiB
# 25/06/11 20:23:21 WARN DAGScheduler: Broadcasting large task binary with size 2031.6 KiB
# 25/06/11 20:23:21 WARN DAGScheduler: Broadcasting large task binary with size 2041.0 KiB
# 25/06/11 20:23:21 WARN DAGScheduler: Broadcasting large task binary with size 2041.5 KiB
# 25/06/11 20:23:21 WARN DAGScheduler: Broadcasting large task binary with size 2041.9 KiB
# 25/06/11 20:23:22 WARN DAGScheduler: Broadcasting large task binary with size 2042.3 KiB
# 25/06/11 20:23:22 WARN DAGScheduler: Broadcasting large task binary with size 2042.9 KiB
# 25/06/11 20:23:22 WARN DAGScheduler: Broadcasting large task binary with size 2043.8 KiB
# 25/06/11 20:23:22 WARN DAGScheduler: Broadcasting large task binary with size 2044.8 KiB
# 25/06/11 20:23:22 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 25/06/11 20:23:22 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 25/06/11 20:23:22 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 25/06/11 20:23:22 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 25/06/11 20:23:23 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 25/06/11 20:23:23 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 25/06/11 20:23:23 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 25/06/11 20:23:23 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 25/06/11 20:23:23 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 25/06/11 20:23:23 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 25/06/11 20:23:23 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 25/06/11 20:23:23 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 25/06/11 20:23:24 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 25/06/11 20:23:24 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 25/06/11 20:23:24 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 25/06/11 20:23:24 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 25/06/11 20:23:24 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 25/06/11 20:23:24 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 25/06/11 20:23:24 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 25/06/11 20:23:24 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 25/06/11 20:23:25 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 25/06/11 20:23:25 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 25/06/11 20:23:25 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 25/06/11 20:23:25 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 25/06/11 20:23:25 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 25/06/11 20:23:25 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 25/06/11 20:23:25 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:25 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:25 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:26 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:26 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:26 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:26 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:26 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:26 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:26 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:27 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:27 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:27 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:27 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:27 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:27 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:27 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:27 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:28 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:28 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:28 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:28 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:28 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:28 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:28 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:28 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:28 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:29 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:29 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:29 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:29 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:29 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:29 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:29 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:30 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:30 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:30 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:30 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:30 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:30 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:30 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:30 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:31 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:31 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:31 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:31 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:31 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:31 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:31 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:32 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:32 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/06/11 20:23:32 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:32 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:32 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:32 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:32 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:32 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:33 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:33 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:33 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:33 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:33 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:33 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:33 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:33 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:34 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:34 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:34 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:34 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:34 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:34 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:34 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:35 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:35 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:35 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:35 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:35 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:35 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:35 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:36 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:36 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:36 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:36 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:36 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:36 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:36 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:36 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:37 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:37 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:37 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:37 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:37 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:37 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:37 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:38 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:38 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:38 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:38 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:38 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:38 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# ✅ Entrenamiento completado en 118.2s

# %% [markdown]
# # EVALUACIÓN COMPLETA

# %%
print("=== EVALUACIÓN COMPLETA DEL MODELO ===")

# Predicciones en validación
predictions = gbt_model.transform(val_df)

# Calcular todas las métricas
f1_evaluator = MulticlassClassificationEvaluator(
    labelCol=target_col, predictionCol="prediction", metricName="f1")
f1_score = f1_evaluator.evaluate(predictions)

auc_evaluator = BinaryClassificationEvaluator(
    labelCol=target_col, rawPredictionCol="rawPrediction", metricName="areaUnderROC")
auc_score = auc_evaluator.evaluate(predictions)

accuracy_evaluator = MulticlassClassificationEvaluator(
    labelCol=target_col, predictionCol="prediction", metricName="accuracy")
accuracy = accuracy_evaluator.evaluate(predictions)

precision_evaluator = MulticlassClassificationEvaluator(
    labelCol=target_col, predictionCol="prediction", metricName="weightedPrecision")
precision = precision_evaluator.evaluate(predictions)

recall_evaluator = MulticlassClassificationEvaluator(
    labelCol=target_col, predictionCol="prediction", metricName="weightedRecall")
recall = recall_evaluator.evaluate(predictions)

print("\n=== RESULTADOS FINALES PARA TORNEO ===")
print(f"🎯 F1-Score:  {f1_score:.4f}")
print(f"📊 AUC:       {auc_score:.4f}")
print(f"🎯 Accuracy:  {accuracy:.4f}")
print(f"📈 Precision: {precision:.4f}")
print(f"📉 Recall:    {recall:.4f}")
print(f"⏱️  Tiempo:    {training_time:.1f}s")
# Out:
# === EVALUACIÓN COMPLETA DEL MODELO ===
# 25/06/11 20:23:39 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:39 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:40 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:41 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:23:41 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# === RESULTADOS FINALES PARA TORNEO ===
# 🎯 F1-Score:  0.8450
# 📊 AUC:       0.9155
# 🎯 Accuracy:  0.8468
# 📈 Precision: 0.8479
# 📉 Recall:    0.8468
# ⏱️  Tiempo:    118.2s

# %% [markdown]
# # ANÁLISIS DE IMPORTANCIA DE CARACTERÍSTICAS

# %%
print("\n=== ANÁLISIS DE IMPORTANCIA DE CARACTERÍSTICAS ===")

if hasattr(gbt_model, 'featureImportances'):
    importances = gbt_model.featureImportances.toArray()
    
    print("Top 10 características más importantes:")
    feature_importance_pairs = [(i, imp) for i, imp in enumerate(importances)]
    feature_importance_pairs.sort(key=lambda x: x[1], reverse=True)
    
    for i, (feature_idx, importance) in enumerate(feature_importance_pairs[:10]):
        print(f"  {i+1:2d}. Característica {feature_idx:3d}: {importance:.4f}")
else:
    print("Importancias no disponibles")
# Out:
# === ANÁLISIS DE IMPORTANCIA DE CARACTERÍSTICAS ===
# Top 10 características más importantes:
#    1. Característica  21: 0.2540
#    2. Característica   1: 0.1019
#    3. Característica   0: 0.1005
#    4. Característica  10: 0.0695
#    5. Característica  20: 0.0672
#    6. Característica  15: 0.0548
#    7. Característica  12: 0.0512
#    8. Característica  22: 0.0344
#    9. Característica  13: 0.0327
#   10. Característica  16: 0.0257

# %% [markdown]
# # MATRIZ DE CONFUSIÓN Y ESTADÍSTICAS FINALES

# %%
# BLOQUE 11: MATRIZ DE CONFUSIÓN
print("\n=== MATRIZ DE CONFUSIÓN ===")
confusion_matrix = predictions.groupBy(target_col, "prediction").count().orderBy(target_col, "prediction")
confusion_matrix.show()

# Calcular métricas de la matriz de confusión manualmente (CORREGIDO)
conf_data = confusion_matrix.collect()

# Inicializar valores
tn = fp = fn = tp = 0

# Buscar valores en los datos recolectados
for row in conf_data:
    actual = row[target_col]  # Valor real
    predicted = row['prediction']  # Predicción
    count = row['count']  # Cantidad
    
    if actual == 0 and predicted == 0.0:
        tn = count  # True Negative
    elif actual == 0 and predicted == 1.0:
        fp = count  # False Positive
    elif actual == 1 and predicted == 0.0:
        fn = count  # False Negative
    elif actual == 1 and predicted == 1.0:
        tp = count  # True Positive

print(f"\nMétricas detalladas:")
print(f"True Positives:  {tp}")
print(f"True Negatives:  {tn}")
print(f"False Positives: {fp}")
print(f"False Negatives: {fn}")

# Calcular métricas manualmente
if tp + fp > 0:
    precision_manual = tp / (tp + fp)
    print(f"Precision manual: {precision_manual:.4f}")
else:
    print("Precision manual: No se puede calcular (tp + fp = 0)")

if tp + fn > 0:
    recall_manual = tp / (tp + fn)
    print(f"Recall manual: {recall_manual:.4f}")
else:
    print("Recall manual: No se puede calcular (tp + fn = 0)")

if tp + fp > 0 and tp + fn > 0:
    f1_manual = 2 * (precision_manual * recall_manual) / (precision_manual + recall_manual)
    print(f"F1-Score manual: {f1_manual:.4f}")
# Out:
# === MATRIZ DE CONFUSIÓN ===
# 25/06/11 20:43:20 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:43:21 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:43:21 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# +-----------+----------+-----+
# |is_canceled|prediction|count|
# +-----------+----------+-----+
# |          0|       0.0| 5919|
# |          0|       1.0|  566|
# |          1|       0.0| 1137|
# |          1|       1.0| 3496|
# +-----------+----------+-----+
# 25/06/11 20:43:22 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:43:22 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/06/11 20:43:22 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# Métricas detalladas:
# True Positives:  3496
# True Negatives:  5919
# False Positives: 566
# False Negatives: 1137
# Precision manual: 0.8607
# Recall manual: 0.7546
# F1-Score manual: 0.8041

# %% [markdown]
# # COMPARACIÓN CON RESULTADOS PREVIOS

# %%
print("\n=== COMPARACIÓN CON EXPERIMENTOS PREVIOS ===")
previous_best_f1 = 0.8580  # De experiment_results.json
improvement = f1_score - previous_best_f1

print(f"F1-Score previo (con Grid Search): {previous_best_f1:.4f}")
print(f"F1-Score actual (sin Grid Search): {f1_score:.4f}")
print(f"Diferencia: {improvement:+.4f}")

if improvement >= -0.01:  # Tolerancia de 1%
    print("✅ EXCELENTE: Resultados similares sin Grid Search")
elif improvement >= -0.02:  # Tolerancia de 2%
    print("👍 BUENO: Pequeña pérdida aceptable por simplicidad")
else:
    print("⚠️  NOTA: Pérdida significativa, pero modelo más eficiente")
# Out:
# === COMPARACIÓN CON EXPERIMENTOS PREVIOS ===
# F1-Score previo (con Grid Search): 0.8580
# F1-Score actual (sin Grid Search): 0.8450
# Diferencia: -0.0130
# 👍 BUENO: Pequeña pérdida aceptable por simplicidad

# %% [markdown]
# # ESTADÍSTICAS FINALES Y GUARDADO

# %%
print("\n=== ESTADÍSTICAS FINALES ===")
print(f"✅ Dimensión de características: {feature_dimension}")
print(f"✅ Tiempo total de ejecución: {training_time:.1f}s")
print(f"✅ Configuración basada en: Mejores parámetros previos")
print(f"✅ Pipeline simplificado: {len(preprocessing_stages)} etapas")

# Guardar resultados
final_results = {
    "model": "Gradient Boosted Trees (Configuración Óptima)",
    "methodology": "Sin Grid Search - Parámetros basados en experimentos previos",
    "performance_level": performance,
    "metrics": {
        "f1_score": float(f1_score),
        "auc_score": float(auc_score),
        "accuracy": float(accuracy),
        "precision": float(precision),
        "recall": float(recall)
    },
    "training_info": {
        "training_time_seconds": training_time,
        "feature_dimension": feature_dimension,
        "pipeline_stages": len(preprocessing_stages)
    },
    "configuration": {
        "maxDepth": gbt_final.getMaxDepth(),
        "maxIter": gbt_final.getMaxIter(),
        "stepSize": gbt_final.getStepSize(),
        "subsamplingRate": gbt_final.getSubsamplingRate(),
        "minInstancesPerNode": gbt_final.getMinInstancesPerNode()
    },
    "comparison_with_grid_search": {
        "previous_best_f1": previous_best_f1,
        "current_f1": float(f1_score),F1-Score: 0.8450
        "difference": float(improvement),
        "time_saved": "Grid Search evitado - Crasheo de maquina virtual evitado"
    },
    "experiment_timestamp": time.strftime("%Y-%m-%d %H:%M:%S")
}

with open("gbt_final_results.json", "w") as f:
    json.dump(final_results, f, indent=2)

print("\n📁 Resultados guardados en 'gbt_final_results.json'")
print("🚀 MODELO LISTO PARA TORNEO - VERSIÓN EFICIENTE!")
print(f"⚡ Tiempo total: {training_time:.1f}s (vs ~3426s con Grid Search)")
# Out:
# === ESTADÍSTICAS FINALES ===
# ✅ Dimensión de características: 27
# ✅ Tiempo total de ejecución: 118.2s
# ✅ Configuración basada en: Mejores parámetros previos
# ✅ Pipeline simplificado: 8 etapas
#
# 📁 Resultados guardados en 'gbt_final_results.json'
# 🚀 MODELO LISTO PARA TORNEO - VERSIÓN EFICIENTE!
# ⚡ Tiempo total: 118.2s (vs ~3426s con Grid Search)

# %% [markdown]
# # MODELO FINAL PARA PRODUCCIÓN

# %%
print("\n=== PREPARANDO MODELO PARA TORNEO ===")
print("Configuración final lista para entrega:")
print(f"- Algoritmo: Gradient Boosted Trees")
print(f"- F1-Score: {f1_score:.4f}")
print(f"- Tiempo entrenamiento: {training_time:.1f}s << Crasheo de pc")
print(f"- Pipeline optimizado: {len(preprocessing_stages)} etapas")
print("- Basado en mejores parámetros encontrados experimentalmente")

# Limpiar cache
train_df.unpersist()
val_df.unpersist()

# Detener Spark
print("\n=== FINALIZANDO ===")
spark.stop()
print("✅ PROCESO COMPLETADO - MODELO LISTO PARA COMPETICIÓN!")
# Out:
# === PREPARANDO MODELO PARA TORNEO ===
# Configuración final lista para entrega:
# - Algoritmo: Gradient Boosted Trees
# - F1-Score: 0.8450
# - Tiempo entrenamiento: 118.2s << Crasheo de pc
# - Pipeline optimizado: 8 etapas
# - Basado en mejores parámetros encontrados experimentalmente
#
# === FINALIZANDO ===
# ✅ PROCESO COMPLETADO - MODELO LISTO PARA COMPETICIÓN!
